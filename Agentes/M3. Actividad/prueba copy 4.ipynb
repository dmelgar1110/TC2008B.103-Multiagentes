# %% [markdown]
# ## **Dependencias**

# %%
# !pip install -q agentpy numpy matplotlib seaborn
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## **Imports y estilo**

# %%
import agentpy as ap
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(context="notebook", style="whitegrid")

# %% [markdown]
# ## **Parámetros**

# %%
#params = {
#    'steps': 600,          # duración en ticks (1 tick = 1 s)
#    'green_ns': 20,        # VERDE para Norte-Sur
#    'green_ew': 20,        # VERDE para Este-Oeste
#    'yellow': 3,           # ÁMBAR
#    'all_red': 1,          # ALL-RED (despeje)
#    # Tasas Poisson de arribo (veh/s) por aproximación
#    'lambda_N': 0.10, 'lambda_S': 0.10,
#    'lambda_E': 0.10, 'lambda_W': 0.10,
#    # Cinemática
#    'v_free': 7.0,         # m/s
#    'headway': 8.0,        # m separación mínima
#    # Geometría (intersección centrada en 0,0)
#    'L': 80.0,             # media-calzada (desde centro al extremo de dibujo)
#    'w': 3.5               # ancho de carril
#}

params = {
    'steps': 200,          # duración en ticks (1 tick = 1 s)
    # Semáforos (puedes ajustar los tiempos)
    'green': 20,           # Verde para cada entrada
    'yellow': 3,           # Ámbar
    'all_red': 2,          # All-red (despeje)
    # Tasas Poisson de arribo (veh/s) por entrada
    'lambda_N': 0.08,      # Arribos desde el norte
    'lambda_S': 0.12,      # Arribos desde el sur
    'lambda_E': 0.05,      # Arribos desde el este
    'lambda_W': 0.15,      # Arribos desde el oeste
    # Geometría de la rotonda
    'L': 100.0,            # Largo de acceso (desde el centro hasta el extremo de la calle)
    'w': 3.5,              # Ancho de carril
    'r_in': 20.0,          # Radio interior de la rotonda
    'r_out': 30.0,         # Radio exterior de la rotonda
    # Cinemática
    'v_free': 4.0,         # m/s velocidad libre (antes 7.0, ahora más lento)
    'headway': 16.0,       # m separación mínima entre autos (AUMENTADA)
    # Otros
    'n_entries': 4,        # Número de entradas/salidas (N, S, E, W)
}

# %% [markdown]
# ## **Controlador de semáforos**

# %% [markdown]
# class FourWaySignals(ap.Agent):
#     """Control adaptativo: fase NS y fase EW, con subestados G/Y/AR."""
#
#     def setup(self, green_ns, green_ew, yellow, all_red):
#         self.g_ns, self.g_ew = int(green_ns), int(green_ew)
#         self.y, self.ar = int(yellow), int(all_red)
#         self.phase = 0          # 0 = NS verde, 1 = EW verde
#         self.sub = 'G'          # 'G','Y','AR'
#         self.t_in = 0
#         self.timeline = []
#         # Parámetros heurísticos
#         self.theta = 3
#         self.Gmin = 5
#         self.Gmax = 20
#
#     def lights(self):
#         L = {d:'R' for d in ['N','S','E','W']}
#         if self.phase == 0:
#             L['N'] = L['S'] = self.sub
#         else:
#             L['E'] = L['W'] = self.sub
#         return L
#
#     @property
#     def green_dirs(self):
#         if self.sub != 'G': return set()
#         return {'N','S'} if self.phase == 0 else {'E','W'}
#
#     def get_queues(self):
#         # Calcula la cantidad de autos esperando en cada dirección
#         m = self.model
#         Q = {'N':0, 'S':0, 'E':0, 'W':0}
#         for c in m.cars:
#             if c.state == 'stop':
#                 Q[c.origin] += 1
#         return Q
#
#     def step(self):
#         self.timeline.append((self.model.t, self.lights()))
#         if self.sub == 'G':
#             Q = self.get_queues()
#             sumQ_NS = Q['N'] + Q['S']
#             sumQ_EW = Q['E'] + Q['W']
#             # Heurística adaptativa
#             if self.phase == 0:
#                 if sumQ_NS > sumQ_EW + self.theta and self.t_in < self.Gmax:
#                     self.t_in += 1  # Extiende verde NS
#                 elif self.t_in >= self.Gmin:
#                     self.sub, self.t_in = 'Y', 0  # Cambia a amarillo
#                 else:
#                     self.t_in += 1
#             else:
#                 if sumQ_EW > sumQ_NS + self.theta and self.t_in < self.Gmax:
#                     self.t_in += 1  # Extiende verde EW
#                 elif self.t_in >= self.Gmin:
#                     self.sub, self.t_in = 'Y', 0
#                 else:
#                     self.t_in += 1
#         elif self.sub == 'Y' and self.t_in >= self.y:
#             self.sub, self.t_in = 'AR', 0
#         elif self.sub == 'AR' and self.t_in >= self.ar:
#             self.phase = 1 - self.phase
#             self.sub, self.t_in = 'G', 0
#         else:
#             self.t_in += 1

# %%
class RoundaboutSignals(ap.Agent):
    """Controlador de semáforos para rotonda: un semáforo por entrada, con heurística adaptativa y tiempos mínimo/máximo de rojo."""

    def setup(self, green, yellow, all_red, n_entries=4):
        self.entries = ['N', 'S', 'E', 'W'][:n_entries]
        self.green = int(green)
        self.yellow = int(yellow)
        self.all_red = int(all_red)
        self.lights_state = {d: {'state': 'G', 't_in': 0, 'red_time': 0, 'last_queue_check': 0} for d in self.entries}
        self.theta = 2
        self.Gmin = 3
        self.Gmax = 14
        self.Rmin = 10
        self.Rmax_base = 30
        self.queue_check_interval = 5
        self.timeline = []

    def lights(self):
        return {d: self.lights_state[d]['state'] for d in self.entries}

    def get_queues(self):
        m = self.model
        Q = {d: 0 for d in self.entries}
        for c in m.cars:
            if c.state == 'stop' and getattr(c, 'at_entry', True):
                Q[c.origin] += 1
        return Q

    def can_enter(self, entry):
        m = self.model
        max_in_roundabout = 12
        n_in = sum([getattr(c, 'state', '') == 'in_roundabout' for c in m.cars])
        if n_in >= max_in_roundabout:
            return False
        entry_angles = {'N': np.pi/2, 'E': 0, 'S': 3*np.pi/2, 'W': np.pi}
        theta_entry = entry_angles[entry]
        r = (m.p.r_in + m.p.r_out) / 2
        min_angular_dist = m.p.headway / r
        for c in m.cars:
            if getattr(c, 'state', None) == 'in_roundabout':
                dtheta = (c.theta - theta_entry) % (2*np.pi)
                if 0 < dtheta < min_angular_dist:
                    return False
        return True

    def step(self):
        self.timeline.append((self.model.t, self.lights()))
        Q = self.get_queues()
        for d in self.entries:
            light = self.lights_state[d]
            fila = Q[d]
            Rmax = max(self.Rmin, self.Rmax_base - fila * 2)
            if light['state'] == 'G':
                if light['last_queue_check'] % self.queue_check_interval == 0:
                    check_queue = True
                else:
                    check_queue = False
                if check_queue and Q[d] > self.theta and self.can_enter(d) and light['t_in'] < self.Gmax:
                    light['t_in'] += 1
                elif light['t_in'] >= self.Gmin:
                    light['state'], light['t_in'], light['red_time'] = 'Y', 0, 0
                    light['last_queue_check'] = 0
                else:
                    light['t_in'] += 1
                light['last_queue_check'] += 1
            elif light['state'] == 'Y' and light['t_in'] >= self.yellow:
                light['state'], light['t_in'], light['red_time'] = 'AR', 0, light['red_time']
                light['last_queue_check'] = 0
            elif light['state'] == 'AR' and light['t_in'] >= self.all_red:
                light['state'], light['t_in'], light['red_time'] = 'R', 0, light['red_time']
                light['last_queue_check'] = 0
            elif light['state'] == 'R':
                light['red_time'] += 1
                # CAMBIO: Si hay autos esperando y hay espacio en la rotonda, cambia a verde aunque no haya pasado el rojo máximo
                if light['red_time'] >= self.Rmin and Q[d] > 0 and self.can_enter(d):
                    light['state'], light['t_in'], light['red_time'] = 'G', 0, 0
                    light['last_queue_check'] = 0
                elif light['red_time'] >= Rmax:
                    light['state'], light['t_in'], light['red_time'] = 'G', 0, 0
                    light['last_queue_check'] = 0
            else:
                light['t_in'] += 1

# %% [markdown]
# ## **Agente Vehículo**

# %%
class Car(ap.Agent):
    """
    Auto para rotonda: espera en la entrada, entra solo con luz verde, sigue trayectoria circular y sale por su destino.
    """

    def setup(self, origin):
        self.origin = origin  # 'N','S','E','W'
        self.state = 'approach'  # 'approach', 'stop', 'in_roundabout', 'exit', 'done'
        self.v = self.model.p.v_free
        self.r_in = self.model.p.r_in
        self.r_out = self.model.p.r_out
        self.r = (self.r_in + self.r_out) / 2  # Radio medio para trayectoria
        self.L = self.model.p.L
        self.w = self.model.p.w
        self.at_entry = True  # True mientras no entra a la rotonda

        # Ángulos de entrada y salida (en radianes)
        entry_angles = {'N': np.pi/2, 'E': 0, 'S': 3*np.pi/2, 'W': np.pi}
        self.theta_entry = entry_angles[origin]
        # Destino aleatorio distinto de origen
        dests = [d for d in ['N','E','S','W'] if d != origin]
        self.destination = np.random.choice(dests)
        self.theta_exit = entry_angles[self.destination]

        # Posición inicial: más lejos de la rotonda
        entry_point = np.array([self.r * np.cos(self.theta_entry), self.r * np.sin(self.theta_entry)])
        direction = np.array([np.cos(self.theta_entry), np.sin(self.theta_entry)])  
        distancia_inicial = self.L * 1.2  
        self.pos = entry_point + direction * distancia_inicial
        self.theta = self.theta_entry  # Ángulo actual (solo cambia en la rotonda)

    def dist_to_entry(self):
        # Distancia a la entrada de la rotonda
        entry_point = np.array([self.r * np.cos(self.theta_entry), self.r * np.sin(self.theta_entry)])
        return np.linalg.norm(self.pos - entry_point)

    def car_ahead(self):
        # Busca el auto más cercano adelante en la misma entrada (en approach o stop)
        my_dist = self.dist_to_entry()
        ahead = None
        min_dist = None
        for c in self.model.cars:
            if c is self: continue
            if c.origin == self.origin and c.state in ['approach', 'stop'] and getattr(c, 'at_entry', True):
                dist = c.dist_to_entry()
                if dist < my_dist:
                    if ahead is None or dist > min_dist:
                        ahead = c
                        min_dist = dist
        return ahead

    def step(self):
        if self.state == 'done':
            return

        # 1. Aproximación a la rotonda
        if self.state == 'approach':
            # Headway: espera si hay un auto adelante muy cerca
            ahead = self.car_ahead()
            if ahead is not None:
                # Si el auto de adelante está demasiado cerca, no avanza
                if self.dist_to_entry() - ahead.dist_to_entry() < self.model.p.headway:
                    return
            # Si está cerca de la entrada, verifica semáforo
            if self.dist_to_entry() < 8.0:
                lights = self.model.ctrl.lights()
                if lights[self.origin] == 'G':
                    # Al entrar a la rotonda, colocar el auto exactamente en el punto de entrada circular
                    self.pos = np.array([self.r * np.cos(self.theta_entry), self.r * np.sin(self.theta_entry)])
                    self.theta = self.theta_entry
                    self.state = 'in_roundabout'
                    self.at_entry = False
                else:
                    self.state = 'stop'
                    return
            else:
                # Avanza hacia la entrada (siempre hacia el centro)
                direction = (np.array([self.r * np.cos(self.theta_entry), self.r * np.sin(self.theta_entry)]) - self.pos)
                direction = direction / np.linalg.norm(direction)
                self.pos += direction * self.v * 1.0  # dt=1s
                return

        # 2. Esperando en la entrada
        if self.state == 'stop':
            # Headway: espera si hay un auto adelante muy cerca
            ahead = self.car_ahead()
            if ahead is not None:
                if self.dist_to_entry() - ahead.dist_to_entry() < self.model.p.headway:
                    return
            lights = self.model.ctrl.lights()
            if lights[self.origin] == 'G':
                # Al entrar a la rotonda, colocar el auto exactamente en el punto de entrada circular
                self.pos = np.array([self.r * np.cos(self.theta_entry), self.r * np.sin(self.theta_entry)])
                self.theta = self.theta_entry
                self.state = 'in_roundabout'
                self.at_entry = False
            else:
                return

        # 3. Dentro de la rotonda: avanza por el círculo
        if self.state == 'in_roundabout':
            # --- Headway angular: no avanzar si hay un auto adelante muy cerca ---
            # Buscar autos en la rotonda (excepto yo) cuyo ángulo esté adelante y cerca
            ahead_cars = []
            for c in self.model.cars:
                if c is self: continue
                if getattr(c, 'state', None) == 'in_roundabout':
                    # Diferencia angular positiva (en sentido antihorario)
                    dtheta = (c.theta - self.theta) % (2*np.pi)
                    if 0 < dtheta < (self.model.p.headway / self.r):
                        ahead_cars.append((dtheta, c))
            if ahead_cars:
                # Hay un auto adelante muy cerca, no avanzar
                return

            # Avanza un ángulo proporcional a la velocidad
            dtheta = self.v / self.r  # radianes por tick
            self.theta += dtheta 
            self.pos = np.array([self.r * np.cos(self.theta), self.r * np.sin(self.theta)])

            # Verifica si llegó a su salida
            # Considera un margen angular pequeño
            if abs((self.theta - self.theta_exit + np.pi) % (2*np.pi) - np.pi) < 0.1:
                self.state = 'exit'

        # 4. Salida: avanza en línea recta hacia afuera
        if self.state == 'exit':
            direction = np.array([np.cos(self.theta_exit), np.sin(self.theta_exit)])
            self.pos += direction * self.v * 1.0
            # Si está suficientemente lejos del centro, termina
            if np.linalg.norm(self.pos) > self.L:
                self.state = 'done'

# %% [markdown]
# ## **Modelo con arribos Poisson y listas de agentes**

# %%
class RoundaboutModel(ap.Model):
    """
    Modelo de rotonda con arribos Poisson, semáforos adaptativos y agentes vehículo.
    """

    def setup(self):
        p = self.p
        self.ctrl = RoundaboutSignals(self, p.green, p.yellow, p.all_red, p.n_entries)
        self.cars = ap.AgentList(self, 0, Car)
        self.spawn_counts = {d: 0 for d in ['N', 'S', 'E', 'W']}
        self.log = []

    def headway_ahead(self, me):
        """
        Busca el auto más cercano adelante en la misma trayectoria (solo para la entrada, no en la rotonda).
        """
        if me.state != 'approach':
            return None
        same = [c for c in self.cars if c is not me and c.state == 'approach' and c.origin == me.origin]
        if not same:
            return None
        # El que está más cerca de la entrada pero adelante de mí
        my_dist = me.dist_to_entry()
        ahead = [(c.dist_to_entry(), c) for c in same if c.dist_to_entry() < my_dist]
        if not ahead:
            return None
        return min(ahead, key=lambda x: x[0])[1]

    def spawn_poisson(self, origin, lam):
        k = np.random.poisson(lam)
        for _ in range(k):
            entry_angles = {'N': np.pi/2, 'E': 0, 'S': 3*np.pi/2, 'W': np.pi}
            theta_entry = entry_angles[origin]
            r = (self.p.r_in + self.p.r_out) / 2
            L = self.p.L
            entry_point = np.array([r * np.cos(theta_entry), r * np.sin(theta_entry)])
            direction = np.array([np.cos(theta_entry), np.sin(theta_entry)])  
            distancia_inicial = L * 1.2
            pos_entry = entry_point + direction * distancia_inicial
            too_close = any(
                np.linalg.norm(c.pos - pos_entry) < self.p.headway
                for c in self.cars if hasattr(c, 'pos')
            )
            if not too_close:
                self.cars.append(Car(self, origin=origin))
                self.spawn_counts[origin] += 1

    def step(self):
        # 1) arribos
        self.spawn_poisson('N', self.p.lambda_N)
        self.spawn_poisson('S', self.p.lambda_S)
        self.spawn_poisson('E', self.p.lambda_E)
        self.spawn_poisson('W', self.p.lambda_W)

        # 2) señales
        self.ctrl.step()

        # 3) autos
        self.cars.step()

        # 4) limpieza de autos terminados
        self.cars = ap.AgentList(self, [c for c in self.cars if c.state != 'done'], Car)

# %% [markdown]
# ## **Función de animación (animation_plot)**

# %%
def draw_roundabout(ax, L, w, r_in, r_out, model):
    ax.clear()
    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect('equal')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f"Rotonda | t = {model.t}s")
    
    # --- Calles de acceso: dos carriles por acceso (entrada y salida), bien separados y del mismo color ---
    entry_angles = {'N': np.pi/2, 'E': 0, 'S': 3*np.pi/2, 'W': np.pi}
    lane_gap = 5 * w  # Aumenta aún más la separación entre los centros de los dos carriles
    lane_length = L - r_out  # largo visible de los carriles desde el borde de la rotonda
    
    for label, theta in entry_angles.items():
        dir_vec = np.array([np.cos(theta), np.sin(theta)])
        perp_vec = np.array([-np.sin(theta), np.cos(theta)])
        entry_center = dir_vec * (r_out + lane_length/2) + perp_vec * (lane_gap/2)
        exit_center = dir_vec * (r_out + lane_length/2) - perp_vec * (lane_gap/2)
        ax.add_patch(plt.Rectangle(
            entry_center - dir_vec * (lane_length/2) - perp_vec * (w/2),
            lane_length, w,
            angle=np.degrees(theta), color='#e0e0e0', zorder=0
        ))
        ax.add_patch(plt.Rectangle(
            exit_center - dir_vec * (lane_length/2) - perp_vec * (w/2),
            lane_length, w,
            angle=np.degrees(theta), color='#e0e0e0', zorder=0
        ))
    
    # --- Rotonda: anillo ---
    circ1 = plt.Circle((0, 0), r_out, color='black', fill=True, zorder=1)
    circ2 = plt.Circle((0, 0), r_in, color='white', fill=True, zorder=2)
    ax.add_patch(circ1)
    ax.add_patch(circ2)
    
    # --- Líneas de alto (en cada entrada, alineadas con el carril de entrada) ---
    for label, theta in entry_angles.items():
        dir_vec = np.array([np.cos(theta), np.sin(theta)])
        perp_vec = np.array([-np.sin(theta), np.cos(theta)])
        stop_center = dir_vec * (r_out + 2) + perp_vec * (lane_gap/2)
        dx, dy = perp_vec
        ax.plot([stop_center[0] - 6*dx, stop_center[0] + 6*dx],
                [stop_center[1] - 6*dy, stop_center[1] + 6*dy],
                color='yellow', lw=2, zorder=3)
    
    # --- Semáforos: círculos en la entrada de cada calle ---
    if hasattr(model, 'ctrl') and hasattr(model.ctrl, 'lights'):
        lights = model.ctrl.lights()
        color_map = {'R': '#d32f2f', 'Y': '#f9a825', 'G': '#388e3c', 'AR': '#000000'}
        for d, theta in entry_angles.items():
            x, y = (r_out + 5) * np.cos(theta), (r_out + 5) * np.sin(theta)
            state = lights.get(d, 'R')
            ax.add_patch(plt.Circle((x, y), 2.0, color=color_map[state], zorder=4))
    
    # --- Etiquetas de entradas ---
    for label, theta in entry_angles.items():
        x, y = (L + 10) * np.cos(theta), (L + 10) * np.sin(theta)
        ax.text(x, y, label, fontsize=16, fontweight='bold', color='black', ha='center', va='center', zorder=10)
    
    # --- Autos: ajustar posición según carril de entrada/salida ---
    if hasattr(model, 'cars') and len(model.cars) > 0:
        xs, ys, cs = [], [], []
        for c in model.cars:
            pos = np.array(c.pos)
            color = '#9c27b0'  # morado por defecto
            if c.state == 'stop':
                color = '#ff9800'
            elif c.state == 'in_roundabout':
                color = '#1976d2'
            elif c.state == 'exit':
                color = '#43a047'
            # Ajuste de posición para carril de entrada/salida
            if c.state in ['approach', 'stop'] and hasattr(c, 'origin'):
                theta = entry_angles.get(c.origin, 0)
                perp_vec = np.array([-np.sin(theta), np.cos(theta)])
                # Carril de entrada: +lane_gap/2 (derecho para sur, izquierdo para norte, etc.)
                pos = pos + perp_vec * (lane_gap/2)
            elif c.state == 'exit' and hasattr(c, 'theta_exit'):
                theta = c.theta_exit
                perp_vec = np.array([-np.sin(theta), np.cos(theta)])
                # Carril de salida: -lane_gap/2
                pos = pos - perp_vec * (lane_gap/2)
            # Si está en la rotonda, no se ajusta
            xs.append(pos[0])
            ys.append(pos[1])
            cs.append(color)
        ax.scatter(xs, ys, s=80, c=cs, edgecolor='k', linewidth=1.0, zorder=5)
    
def my_plot_roundabout(model, ax):
    draw_roundabout(ax, model.p.L, model.p.w, model.p.r_in, model.p.r_out, model)

# %% [markdown]
# ## **Correr animación**

# %%
fig, ax = plt.subplots(figsize=(6,6))
model = RoundaboutModel(params)
anim = ap.animate(model, fig, ax, my_plot_roundabout)
from IPython.display import HTML
HTML(anim.to_jshtml())
# Out:
# Intentando crear 0 autos en N (t=1)
# Intentando crear 0 autos en S (t=1)
# Intentando crear 0 autos en E (t=1)
# Intentando crear 0 autos en W (t=1)
# Intentando crear 0 autos en N (t=2)
# Intentando crear 0 autos en S (t=2)
# Intentando crear 0 autos en E (t=2)
# Intentando crear 0 autos en W (t=2)
# Intentando crear 0 autos en N (t=3)
# Intentando crear 0 autos en S (t=3)
# Intentando crear 0 autos en E (t=3)
# Intentando crear 0 autos en W (t=3)
# Intentando crear 0 autos en N (t=4)
# Intentando crear 0 autos en S (t=4)
# Intentando crear 0 autos en E (t=4)
# Intentando crear 1 autos en W (t=4)
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=5)
# Intentando crear 1 autos en S (t=5)
# Intentando crear 0 autos en E (t=5)
# Intentando crear 0 autos en W (t=5)
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999973), np.float64(-141.0)), estado: approach, origen: S, destino: N
# Intentando crear 0 autos en N (t=6)
# Intentando crear 1 autos en S (t=6)
# Intentando crear 1 autos en E (t=6)
# Intentando crear 0 autos en W (t=6)
# Carro en (np.float64(-133.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999975), np.float64(-137.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(141.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Intentando crear 0 autos en N (t=7)
# Intentando crear 0 autos en S (t=7)
# Intentando crear 1 autos en E (t=7)
# Intentando crear 0 autos en W (t=7)
# Carro en (np.float64(-129.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999975), np.float64(-133.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(137.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Intentando crear 0 autos en N (t=4)
# Intentando crear 0 autos en S (t=4)
# Intentando crear 0 autos en E (t=4)
# Intentando crear 1 autos en W (t=4)
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=5)
# Intentando crear 1 autos en S (t=5)
# Intentando crear 0 autos en E (t=5)
# Intentando crear 0 autos en W (t=5)
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999973), np.float64(-141.0)), estado: approach, origen: S, destino: N
# Intentando crear 0 autos en N (t=6)
# Intentando crear 1 autos en S (t=6)
# Intentando crear 1 autos en E (t=6)
# Intentando crear 0 autos en W (t=6)
# Carro en (np.float64(-133.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999975), np.float64(-137.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(141.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Intentando crear 0 autos en N (t=7)
# Intentando crear 0 autos en S (t=7)
# Intentando crear 1 autos en E (t=7)
# Intentando crear 0 autos en W (t=7)
# Carro en (np.float64(-129.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999975), np.float64(-133.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(137.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Intentando crear 1 autos en N (t=8)
# Intentando crear 1 autos en S (t=8)
# Intentando crear 0 autos en E (t=8)
# Intentando crear 0 autos en W (t=8)
# Carro en (np.float64(-125.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999977), np.float64(-129.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(133.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(141.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=9)
# Intentando crear 0 autos en S (t=9)
# Intentando crear 0 autos en E (t=9)
# Intentando crear 0 autos en W (t=9)
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999977), np.float64(-125.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(129.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(137.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=10)
# Intentando crear 0 autos en S (t=10)
# Intentando crear 0 autos en E (t=10)
# Intentando crear 0 autos en W (t=10)
# Carro en (np.float64(-117.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999977), np.float64(-121.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(125.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(133.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=11)
# Intentando crear 0 autos en S (t=11)
# Intentando crear 0 autos en E (t=11)
# Intentando crear 0 autos en W (t=11)
# Intentando crear 1 autos en N (t=8)
# Intentando crear 1 autos en S (t=8)
# Intentando crear 0 autos en E (t=8)
# Intentando crear 0 autos en W (t=8)
# Carro en (np.float64(-125.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999977), np.float64(-129.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(133.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(141.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=9)
# Intentando crear 0 autos en S (t=9)
# Intentando crear 0 autos en E (t=9)
# Intentando crear 0 autos en W (t=9)
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999977), np.float64(-125.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(129.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(137.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=10)
# Intentando crear 0 autos en S (t=10)
# Intentando crear 0 autos en E (t=10)
# Intentando crear 0 autos en W (t=10)
# Carro en (np.float64(-117.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999977), np.float64(-121.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(125.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(133.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=11)
# Intentando crear 0 autos en S (t=11)
# Intentando crear 0 autos en E (t=11)
# Intentando crear 0 autos en W (t=11)
# Carro en (np.float64(-113.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999979), np.float64(-117.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(121.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(129.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=12)
# Intentando crear 0 autos en S (t=12)
# Intentando crear 0 autos en E (t=12)
# Intentando crear 1 autos en W (t=12)
# Carro en (np.float64(-109.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999979), np.float64(-113.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(117.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(125.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=13)
# Intentando crear 0 autos en S (t=13)
# Intentando crear 0 autos en E (t=13)
# Intentando crear 0 autos en W (t=13)
# Carro en (np.float64(-105.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999998), np.float64(-109.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(113.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(121.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=14)
# Intentando crear 0 autos en S (t=14)
# Intentando crear 0 autos en E (t=14)
# Intentando crear 0 autos en W (t=14)
# Carro en (np.float64(-101.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999998), np.float64(-105.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(109.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(117.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-133.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-113.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999979), np.float64(-117.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(121.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(129.0)), estado: approach, origen: N, destino: E
# Intentando crear 0 autos en N (t=12)
# Intentando crear 0 autos en S (t=12)
# Intentando crear 0 autos en E (t=12)
# Intentando crear 1 autos en W (t=12)
# Carro en (np.float64(-109.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999979), np.float64(-113.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(117.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(125.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=13)
# Intentando crear 0 autos en S (t=13)
# Intentando crear 0 autos en E (t=13)
# Intentando crear 0 autos en W (t=13)
# Carro en (np.float64(-105.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999998), np.float64(-109.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(113.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(121.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=14)
# Intentando crear 0 autos en S (t=14)
# Intentando crear 0 autos en E (t=14)
# Intentando crear 0 autos en W (t=14)
# Carro en (np.float64(-101.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999998), np.float64(-105.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(109.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(117.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-133.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=15)
# Intentando crear 0 autos en S (t=15)
# Intentando crear 0 autos en E (t=15)
# Intentando crear 0 autos en W (t=15)
# Carro en (np.float64(-97.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999982), np.float64(-101.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(105.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(113.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-129.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=16)
# Intentando crear 0 autos en S (t=16)
# Intentando crear 0 autos en E (t=16)
# Intentando crear 0 autos en W (t=16)
# Carro en (np.float64(-93.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999982), np.float64(-97.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(101.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(109.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-125.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=17)
# Intentando crear 0 autos en S (t=17)
# Intentando crear 0 autos en E (t=17)
# Intentando crear 0 autos en W (t=17)
# Carro en (np.float64(-89.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999982), np.float64(-93.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(97.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(105.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=18)
# Intentando crear 0 autos en S (t=18)
# Intentando crear 0 autos en E (t=18)
# Intentando crear 0 autos en W (t=18)
# Intentando crear 0 autos en N (t=15)
# Intentando crear 0 autos en S (t=15)
# Intentando crear 0 autos en E (t=15)
# Intentando crear 0 autos en W (t=15)
# Carro en (np.float64(-97.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999982), np.float64(-101.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(105.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(113.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-129.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=16)
# Intentando crear 0 autos en S (t=16)
# Intentando crear 0 autos en E (t=16)
# Intentando crear 0 autos en W (t=16)
# Carro en (np.float64(-93.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999982), np.float64(-97.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(101.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(109.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-125.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=17)
# Intentando crear 0 autos en S (t=17)
# Intentando crear 0 autos en E (t=17)
# Intentando crear 0 autos en W (t=17)
# Carro en (np.float64(-89.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999982), np.float64(-93.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(97.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999993), np.float64(105.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=18)
# Intentando crear 0 autos en S (t=18)
# Intentando crear 0 autos en E (t=18)
# Intentando crear 0 autos en W (t=18)
# Carro en (np.float64(-85.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999984), np.float64(-89.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(93.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(101.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-117.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=19)
# Intentando crear 0 autos en S (t=19)
# Intentando crear 0 autos en E (t=19)
# Intentando crear 0 autos en W (t=19)
# Carro en (np.float64(-81.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999984), np.float64(-85.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(89.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(97.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-113.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=20)
# Intentando crear 0 autos en S (t=20)
# Intentando crear 0 autos en E (t=20)
# Intentando crear 0 autos en W (t=20)
# Carro en (np.float64(-77.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999986), np.float64(-81.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(85.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(93.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-109.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=21)
# Intentando crear 0 autos en S (t=21)
# Intentando crear 0 autos en E (t=21)
# Intentando crear 0 autos en W (t=21)
# Carro en (np.float64(-73.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999986), np.float64(-77.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(81.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(89.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-105.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-85.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999984), np.float64(-89.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(93.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(101.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-117.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=19)
# Intentando crear 0 autos en S (t=19)
# Intentando crear 0 autos en E (t=19)
# Intentando crear 0 autos en W (t=19)
# Carro en (np.float64(-81.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999984), np.float64(-85.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(89.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(97.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-113.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=20)
# Intentando crear 0 autos en S (t=20)
# Intentando crear 0 autos en E (t=20)
# Intentando crear 0 autos en W (t=20)
# Carro en (np.float64(-77.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999986), np.float64(-81.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(85.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(93.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-109.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=21)
# Intentando crear 0 autos en S (t=21)
# Intentando crear 0 autos en E (t=21)
# Intentando crear 0 autos en W (t=21)
# Carro en (np.float64(-73.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999986), np.float64(-77.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(81.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(89.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-105.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=22)
# Intentando crear 0 autos en S (t=22)
# Intentando crear 0 autos en E (t=22)
# Intentando crear 0 autos en W (t=22)
# Carro en (np.float64(-69.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999986), np.float64(-73.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(77.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(85.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-101.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=23)
# Intentando crear 0 autos en S (t=23)
# Intentando crear 0 autos en E (t=23)
# Intentando crear 0 autos en W (t=23)
# Carro en (np.float64(-65.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999988), np.float64(-69.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(73.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(81.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-97.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=24)
# Intentando crear 0 autos en S (t=24)
# Intentando crear 0 autos en E (t=24)
# Intentando crear 0 autos en W (t=24)
# Carro en (np.float64(-61.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999988), np.float64(-65.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(69.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(77.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-93.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=25)
# Intentando crear 0 autos en S (t=25)
# Intentando crear 0 autos en E (t=25)
# Intentando crear 0 autos en W (t=25)
# Intentando crear 0 autos en N (t=22)
# Intentando crear 0 autos en S (t=22)
# Intentando crear 0 autos en E (t=22)
# Intentando crear 0 autos en W (t=22)
# Carro en (np.float64(-69.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999986), np.float64(-73.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(77.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(85.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-101.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=23)
# Intentando crear 0 autos en S (t=23)
# Intentando crear 0 autos en E (t=23)
# Intentando crear 0 autos en W (t=23)
# Carro en (np.float64(-65.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999988), np.float64(-69.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(73.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(81.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-97.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=24)
# Intentando crear 0 autos en S (t=24)
# Intentando crear 0 autos en E (t=24)
# Intentando crear 0 autos en W (t=24)
# Carro en (np.float64(-61.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999988), np.float64(-65.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(69.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(77.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-93.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=25)
# Intentando crear 0 autos en S (t=25)
# Intentando crear 0 autos en E (t=25)
# Intentando crear 0 autos en W (t=25)
# Carro en (np.float64(-57.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-61.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(65.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(73.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-89.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=26)
# Intentando crear 0 autos en S (t=26)
# Intentando crear 0 autos en E (t=26)
# Intentando crear 0 autos en W (t=26)
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-57.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(61.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(69.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-85.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=27)
# Intentando crear 0 autos en S (t=27)
# Intentando crear 0 autos en E (t=27)
# Intentando crear 0 autos en W (t=27)
# Carro en (np.float64(-49.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-53.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(57.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(65.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-81.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 1 autos en N (t=28)
# Intentando crear 0 autos en S (t=28)
# Intentando crear 0 autos en E (t=28)
# Intentando crear 0 autos en W (t=28)
# Carro en (np.float64(-57.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-61.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(65.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999995), np.float64(73.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-89.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=26)
# Intentando crear 0 autos en S (t=26)
# Intentando crear 0 autos en E (t=26)
# Intentando crear 0 autos en W (t=26)
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-57.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(61.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(69.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-85.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 0 autos en N (t=27)
# Intentando crear 0 autos en S (t=27)
# Intentando crear 0 autos en E (t=27)
# Intentando crear 0 autos en W (t=27)
# Carro en (np.float64(-49.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-53.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(57.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(65.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-81.0), np.float64(-8.74999999999999)), estado: approach, origen: W, destino: S
# Intentando crear 1 autos en N (t=28)
# Intentando crear 0 autos en S (t=28)
# Intentando crear 0 autos en E (t=28)
# Intentando crear 0 autos en W (t=28)
# Carro en (np.float64(-45.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-49.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(53.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(61.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-77.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999991), np.float64(141.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=29)
# Intentando crear 0 autos en S (t=29)
# Intentando crear 0 autos en E (t=29)
# Intentando crear 0 autos en W (t=29)
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-45.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(49.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(57.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-73.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999991), np.float64(137.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=30)
# Intentando crear 0 autos en S (t=30)
# Intentando crear 0 autos en E (t=30)
# Intentando crear 0 autos en W (t=30)
# Carro en (np.float64(-37.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999993), np.float64(-41.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(45.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(53.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-69.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999991), np.float64(133.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=31)
# Intentando crear 0 autos en S (t=31)
# Intentando crear 0 autos en E (t=31)
# Intentando crear 0 autos en W (t=31)
# Carro en (np.float64(-33.0), np.float64(-8.749999999999996)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999993), np.float64(-37.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(41.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(49.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-65.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(129.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-45.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-49.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(53.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(61.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-77.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999991), np.float64(141.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=29)
# Intentando crear 0 autos en S (t=29)
# Intentando crear 0 autos en E (t=29)
# Intentando crear 0 autos en W (t=29)
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-45.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(49.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(57.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-73.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999991), np.float64(137.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=30)
# Intentando crear 0 autos en S (t=30)
# Intentando crear 0 autos en E (t=30)
# Intentando crear 0 autos en W (t=30)
# Carro en (np.float64(-37.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999993), np.float64(-41.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(45.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(53.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-69.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999991), np.float64(133.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=31)
# Intentando crear 0 autos en S (t=31)
# Intentando crear 0 autos en E (t=31)
# Intentando crear 0 autos en W (t=31)
# Carro en (np.float64(-33.0), np.float64(-8.749999999999996)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999993), np.float64(-37.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(41.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(49.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-65.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(129.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=32)
# Intentando crear 0 autos en S (t=32)
# Intentando crear 0 autos en E (t=32)
# Intentando crear 0 autos en W (t=32)
# Carro en (np.float64(-29.0), np.float64(-8.749999999999996)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999995), np.float64(-33.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(37.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(45.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-61.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(125.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=33)
# Intentando crear 0 autos en S (t=33)
# Intentando crear 0 autos en E (t=33)
# Intentando crear 1 autos en W (t=33)
# Carro en (np.float64(-29.0), np.float64(-8.749999999999996)), estado: stop, origen: W, destino: N
# Carro en (np.float64(8.749999999999995), np.float64(-29.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(33.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(41.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-57.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(121.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=34)
# Intentando crear 0 autos en S (t=34)
# Intentando crear 0 autos en E (t=34)
# Intentando crear 0 autos en W (t=34)
# Carro en (np.float64(-24.680682084390675), np.float64(-3.9829551653561492)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(8.749999999999995), np.float64(-29.0)), estado: stop, origen: S, destino: N
# Carro en (np.float64(29.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(37.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(117.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=35)
# Intentando crear 0 autos en S (t=35)
# Intentando crear 0 autos en E (t=35)
# Intentando crear 0 autos en W (t=35)
# Intentando crear 0 autos en N (t=32)
# Intentando crear 0 autos en S (t=32)
# Intentando crear 0 autos en E (t=32)
# Intentando crear 0 autos en W (t=32)
# Carro en (np.float64(-29.0), np.float64(-8.749999999999996)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999995), np.float64(-33.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(37.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999996), np.float64(45.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-61.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(125.0)), estado: approach, origen: N, destino: S
# Intentando crear 0 autos en N (t=33)
# Intentando crear 0 autos en S (t=33)
# Intentando crear 0 autos en E (t=33)
# Intentando crear 1 autos en W (t=33)
# Carro en (np.float64(-29.0), np.float64(-8.749999999999996)), estado: stop, origen: W, destino: N
# Carro en (np.float64(8.749999999999995), np.float64(-29.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(33.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(41.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-57.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(121.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=34)
# Intentando crear 0 autos en S (t=34)
# Intentando crear 0 autos en E (t=34)
# Intentando crear 0 autos en W (t=34)
# Carro en (np.float64(-24.680682084390675), np.float64(-3.9829551653561492)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(8.749999999999995), np.float64(-29.0)), estado: stop, origen: S, destino: N
# Carro en (np.float64(29.0), np.float64(8.75)), estado: approach, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(37.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(117.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=35)
# Intentando crear 0 autos en S (t=35)
# Intentando crear 0 autos en E (t=35)
# Intentando crear 0 autos en W (t=35)
# Carro en (np.float64(-23.73088545206102), np.float64(-7.864164015402948)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(3.982955165356148), np.float64(-24.680682084390675)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(29.0), np.float64(8.75)), estado: stop, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(33.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-49.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(113.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-133.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=36)
# Intentando crear 0 autos en S (t=36)
# Intentando crear 0 autos en E (t=36)
# Intentando crear 0 autos en W (t=36)
# Carro en (np.float64(-22.1748730694821), np.float64(-11.544479388537079)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(7.864164015402947), np.float64(-23.73088545206102)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(24.680682084390675), np.float64(3.9829551653561492)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(29.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-45.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(109.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-129.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=37)
# Intentando crear 1 autos en S (t=37)
# Intentando crear 0 autos en E (t=37)
# Intentando crear 1 autos en W (t=37)
# Carro en (np.float64(-20.05239394710731), np.float64(-14.92988603405981)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(11.544479388537079), np.float64(-22.1748730694821)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(23.73088545206102), np.float64(7.864164015402944)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(29.0)), estado: stop, origen: N, destino: E
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(105.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-125.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999973), np.float64(-141.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: E
# Intentando crear 0 autos en N (t=38)
# Intentando crear 1 autos en S (t=38)
# Intentando crear 0 autos en E (t=38)
# Intentando crear 0 autos en W (t=38)
# Carro en (np.float64(-17.417667733679124), np.float64(-17.933902272488076)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(14.929886034059809), np.float64(-20.05239394710731)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(22.174873069482103), np.float64(11.544479388537072)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-3.9829551653561452), np.float64(24.680682084390675)), estado: in_roundabout, origen: N, destino: E
# Carro en (np.float64(-37.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(101.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999975), np.float64(-137.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: E
# Carro en (np.float64(-23.73088545206102), np.float64(-7.864164015402948)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(3.982955165356148), np.float64(-24.680682084390675)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(29.0), np.float64(8.75)), estado: stop, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(33.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-49.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(113.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-133.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=36)
# Intentando crear 0 autos en S (t=36)
# Intentando crear 0 autos en E (t=36)
# Intentando crear 0 autos en W (t=36)
# Carro en (np.float64(-22.1748730694821), np.float64(-11.544479388537079)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(7.864164015402947), np.float64(-23.73088545206102)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(24.680682084390675), np.float64(3.9829551653561492)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(29.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(-45.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(109.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-129.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Intentando crear 0 autos en N (t=37)
# Intentando crear 1 autos en S (t=37)
# Intentando crear 0 autos en E (t=37)
# Intentando crear 1 autos en W (t=37)
# Carro en (np.float64(-20.05239394710731), np.float64(-14.92988603405981)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(11.544479388537079), np.float64(-22.1748730694821)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(23.73088545206102), np.float64(7.864164015402944)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-8.749999999999998), np.float64(29.0)), estado: stop, origen: N, destino: E
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(105.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-125.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999973), np.float64(-141.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-141.0), np.float64(-8.749999999999982)), estado: approach, origen: W, destino: E
# Intentando crear 0 autos en N (t=38)
# Intentando crear 1 autos en S (t=38)
# Intentando crear 0 autos en E (t=38)
# Intentando crear 0 autos en W (t=38)
# Carro en (np.float64(-17.417667733679124), np.float64(-17.933902272488076)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(14.929886034059809), np.float64(-20.05239394710731)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(22.174873069482103), np.float64(11.544479388537072)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-3.9829551653561452), np.float64(24.680682084390675)), estado: in_roundabout, origen: N, destino: E
# Carro en (np.float64(-37.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(101.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.749999999999975), np.float64(-137.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-137.0), np.float64(-8.749999999999984)), estado: approach, origen: W, destino: E
# Intentando crear 0 autos en N (t=39)
# Intentando crear 0 autos en S (t=39)
# Intentando crear 0 autos en E (t=39)
# Intentando crear 0 autos en W (t=39)
# Carro en (np.float64(-14.337999651811401), np.float64(-20.479789207524966)), estado: in_roundabout, origen: W, destino: N
# Carro en (np.float64(17.933902272488076), np.float64(-17.417667733679128)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(20.052393947107312), np.float64(14.929886034059802)), estado: in_roundabout, origen: E, destino: N
# Carro en (np.float64(-7.864164015402938), np.float64(23.730885452061024)), estado: in_roundabout, origen: N, destino: E
# Carro en (np.float64(-33.0), np.float64(-8.749999999999996)), estado: approach, origen: W, destino: S
# ...
# Carro en (np.float64(20.052393947107312), np.float64(14.929886034059802)), estado: in_roundabout, origen: E, destino: S
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-57.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(29.0), np.float64(8.75)), estado: approach, origen: E, destino: S
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(8.749999999999988), np.float64(-69.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-8.749999999999996), np.float64(57.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(8.749999999999986), np.float64(-81.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(-73.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(85.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(8.749999999999982), np.float64(-97.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(-97.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(101.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-117.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(137.0)), estado: approach, origen: N, destino: W
# Carro en (np.float64(8.749999999999975), np.float64(-137.0)), estado: approach, origen: S, destino: E
# Intentando crear 1 autos en N (t=199)
# Intentando crear 1 autos en S (t=199)
# Intentando crear 0 autos en E (t=199)
# Intentando crear 0 autos en W (t=199)
# Carro en (np.float64(-12.819232683893159), np.float64(21.463160843552505)), estado: in_roundabout, origen: S, destino: W
# Carro en (np.float64(-1.459353585689564), np.float64(24.957369394868824)), estado: in_roundabout, origen: S, destino: W
# Carro en (np.float64(40.93452654245233), np.float64(-10.558144381331275)), estado: exit, origen: N, destino: E
# Carro en (np.float64(8.02001194246779), np.float64(84.98934007603764)), estado: exit, origen: E, destino: N
# Carro en (np.float64(24.149482809949387), np.float64(-6.465483741527708)), estado: in_roundabout, origen: W, destino: E
# Carro en (np.float64(3.982955165356148), np.float64(-24.680682084390675)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(-16.88657951377874), np.float64(-18.434842888531165)), estado: in_roundabout, origen: N, destino: E
# Carro en (np.float64(-23.491136842133113), np.float64(-8.553741278772483)), estado: in_roundabout, origen: N, destino: S
# Carro en (np.float64(18.434842888531172), np.float64(-16.886579513778734)), estado: in_roundabout, origen: W, destino: E
# Carro en (np.float64(8.749999999999993), np.float64(-37.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(-29.0), np.float64(-8.749999999999996)), estado: stop, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-49.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(22.174873069482103), np.float64(11.544479388537072)), estado: in_roundabout, origen: E, destino: S
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-61.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(33.0), np.float64(8.75)), estado: approach, origen: E, destino: S
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(8.749999999999986), np.float64(-73.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-8.749999999999996), np.float64(61.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(8.749999999999984), np.float64(-85.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(-77.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(89.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(8.749999999999982), np.float64(-101.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(-101.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999993), np.float64(105.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-121.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(141.0)), estado: approach, origen: N, destino: W
# Carro en (np.float64(8.749999999999973), np.float64(-141.0)), estado: approach, origen: S, destino: E
# Intentando crear 0 autos en N (t=200)
# Intentando crear 0 autos en S (t=200)
# Intentando crear 0 autos en E (t=200)
# Intentando crear 0 autos en W (t=200)
# Carro en (np.float64(-16.074968551347784), np.float64(19.14668081086588)), estado: in_roundabout, origen: S, destino: W
# Carro en (np.float64(-5.416877009684562), np.float64(24.40609439181023)), estado: in_roundabout, origen: S, destino: W
# Carro en (np.float64(44.93452654245233), np.float64(-10.558144381331275)), estado: exit, origen: N, destino: E
# Carro en (np.float64(8.02001194246779), np.float64(88.98934007603764)), estado: exit, origen: E, destino: N
# Carro en (np.float64(24.871097583986494), np.float64(-2.5354496579149832)), estado: in_roundabout, origen: W, destino: E
# Carro en (np.float64(7.864164015402947), np.float64(-23.73088545206102)), estado: in_roundabout, origen: S, destino: N
# Carro en (np.float64(-13.73388591067814), np.float64(-20.889719428285208)), estado: in_roundabout, origen: N, destino: E
# Carro en (np.float64(-21.828324487687897), np.float64(-12.187052558359014)), estado: in_roundabout, origen: N, destino: S
# Carro en (np.float64(20.88971942828522), np.float64(-13.733885910678122)), estado: in_roundabout, origen: W, destino: E
# Carro en (np.float64(8.749999999999995), np.float64(-33.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(-29.0), np.float64(-8.749999999999996)), estado: stop, origen: W, destino: N
# Carro en (np.float64(8.749999999999991), np.float64(-45.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(20.052393947107312), np.float64(14.929886034059802)), estado: in_roundabout, origen: E, destino: S
# Carro en (np.float64(-41.0), np.float64(-8.749999999999995)), estado: approach, origen: W, destino: N
# Carro en (np.float64(8.74999999999999), np.float64(-57.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(29.0), np.float64(8.75)), estado: approach, origen: E, destino: S
# Carro en (np.float64(-53.0), np.float64(-8.749999999999993)), estado: approach, origen: W, destino: S
# Carro en (np.float64(8.749999999999988), np.float64(-69.0)), estado: approach, origen: S, destino: W
# Carro en (np.float64(-8.749999999999996), np.float64(57.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(8.749999999999986), np.float64(-81.0)), estado: approach, origen: S, destino: E
# Carro en (np.float64(-73.0), np.float64(-8.749999999999991)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(85.0)), estado: approach, origen: N, destino: E
# Carro en (np.float64(8.749999999999982), np.float64(-97.0)), estado: approach, origen: S, destino: N
# Carro en (np.float64(-97.0), np.float64(-8.749999999999988)), estado: approach, origen: W, destino: S
# Carro en (np.float64(-8.749999999999995), np.float64(101.0)), estado: approach, origen: N, destino: S
# Carro en (np.float64(-117.0), np.float64(-8.749999999999986)), estado: approach, origen: W, destino: N
# Carro en (np.float64(-8.749999999999991), np.float64(137.0)), estado: approach, origen: N, destino: W
# Carro en (np.float64(8.749999999999975), np.float64(-137.0)), estado: approach, origen: S, destino: E
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4159d37b9366426d90ccdfc2e1d3826e">
#   <div class="anim-controls">
#     <input id="_anim_slider4159d37b9366426d90ccdfc2e1d3826e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4159d37b9366426d90ccdfc2e1d3826e.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4159d37b9366426d90ccdfc2e1d3826e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4159d37b9366426d90ccdfc2e1d3826e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4159d37b9366426d90ccdfc2e1d3826e"
#              >
#       <label for="_anim_radio1_4159d37b9366426d90ccdfc2e1d3826e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4159d37b9366426d90ccdfc2e1d3826e"
#              checked>
#       <label for="_anim_radio2_4159d37b9366426d90ccdfc2e1d3826e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4159d37b9366426d90ccdfc2e1d3826e"
#              >
#       <label for="_anim_radio3_4159d37b9366426d90ccdfc2e1d3826e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4159d37b9366426d90ccdfc2e1d3826e";
#     var slider_id = "_anim_slider4159d37b9366426d90ccdfc2e1d3826e";
#     var loop_select_id = "_anim_loop_select4159d37b9366426d90ccdfc2e1d3826e";
#     var frames = new Array(201);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjUsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvWftoOwAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAANrBJ
